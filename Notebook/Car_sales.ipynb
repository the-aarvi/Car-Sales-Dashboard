# %% [markdown]
# # **1️⃣ Import Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **2️⃣ Load Dataset**

# %%
# 📂 Load raw dataset
df = pd.read_csv('/content/Car Sales.csv')

# Preview dataset
df.sample(5)
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 3994   C_CND_003995  7/16/2022         Tiana  Female         310000
# 22450  C_CND_022451  12/6/2023        Rafael    Male         510000
# 919    C_CND_000920  3/14/2022       Vincent    Male        1385000
# 5836   C_CND_005837  9/17/2022         Heidy    Male          13500
# 14714  C_CND_014715  6/12/2023         Jimmy    Male        1460000
#
#                                            Dealer_Name     Company    Model  \
# 3994   Progressive Shippers Cooperative Association No      Toyota  4Runner
# 22450                           Chrysler of Tri-Cities  Mitsubishi  Montero
# 919                               Star Enterprises Inc       Lexus    LX470
# 5836                    Ryder Truck Rental and Leasing        Ford   Escort
# 14714                                    Race Car Help       Lexus    LX470
#
#                           Engine Transmission  Color  Price ($)  Dealer_No   \
# 3994           Overhead Camshaft       Manual  Black      25001  53546-9427
# 22450          Overhead Camshaft       Manual  Black      16000  99301-3882
# 919    DoubleÂ Overhead Camshaft         Auto  Black      22500  99301-3882
# 5836           Overhead Camshaft       Manual  Black      11000  06457-3834
# 14714  DoubleÂ Overhead Camshaft         Auto  Black      22000  78758-7841
#
#       Body Style    Phone Dealer_Region
# 3994       Sedan  6022289    Janesville
# 22450        SUV  8734769         Pasco
# 919          SUV  7864153    Greenville
# 5836   Passenger  8512115    Middletown
# 14714        SUV  6348275        Austin

# %% [markdown]
# # **3️⃣ Explore Dataset**

# %%
# Shape of dataset
df.shape
# Out:
# (23906, 16)

# %%
# 🔍 Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23905 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %%
# 📊 Statistical Summary
df.describe()
# Out:
#        Annual Income     Price ($)         Phone
# count   2.390600e+04  23906.000000  2.390600e+04
# mean    8.308403e+05  28090.247846  7.497741e+06
# std     7.200064e+05  14788.687608  8.674920e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746495e+06
# 50%     7.350000e+05  23000.000000  7.496198e+06
# 75%     1.175750e+06  34000.000000  8.248146e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %%
# 🧩 Check Missing Values
df.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    1
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %% [markdown]
# # **4️⃣ Data Cleaning & Transformation**

# %%
# ✏️ Rename Columns for Readability
df = df.rename(columns={
    'Annual Income'  : 'Annul_Income',
    'Body Style' : 'Body_Style	',
    'Dealer_No ' : 'Dealer_No',
    'Price ($)' : 'Price'
})

# %%
# 🗑️ Drop Unnecessary Columns
df = df.drop(['Engine', 'Dealer_No', 'Customer Name', 'Phone', 'Dealer_Name'], axis=1)

# %%
# 🧹 Drop Missing Values
df = df.dropna()

# %%
# 📆 Convert Order_date to DateTime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df
# Out:
#              Car_id       Date  Gender  Annul_Income    Company       Model  \
# 0      C_CND_000001 2022-01-02    Male         13500       Ford  Expedition
# 1      C_CND_000002 2022-01-02    Male       1480000      Dodge     Durango
# 2      C_CND_000003 2022-01-02    Male       1035000   Cadillac    Eldorado
# 3      C_CND_000004 2022-01-02    Male         13500     Toyota      Celica
# 4      C_CND_000005 2022-01-02    Male       1465000      Acura          TL
# ...             ...        ...     ...           ...        ...         ...
# 23901  C_CND_023902 2023-12-31    Male         13500   Plymouth     Voyager
# 23902  C_CND_023903 2023-12-31  Female        900000  Chevrolet       Prizm
# 23903  C_CND_023904 2023-12-31    Male        705000        BMW        328i
# 23904  C_CND_023905 2023-12-31    Male         13500  Chevrolet       Metro
# 23905  C_CND_023906 2023-12-31    Male       1225000      Lexus       ES300
#
#       Transmission       Color  Price Body_Style\t Dealer_Region
# 0             Auto       Black  26000          SUV    Middletown
# 1             Auto       Black  19000          SUV        Aurora
# 2           Manual         Red  31500    Passenger    Greenville
# 3           Manual  Pale White  14000          SUV         Pasco
# 4             Auto         Red  24500    Hatchback    Janesville
# ...            ...         ...    ...          ...           ...
# 23901       Manual         Red  12000    Passenger         Pasco
# 23902         Auto       Black  16000      Hardtop    Middletown
# 23903       Manual         Red  21000        Sedan    Scottsdale
# 23904         Auto       Black  31000    Passenger        Austin
# 23905         Auto  Pale White  27500      Hardtop    Middletown
#
# [23906 rows x 11 columns]

# %% [markdown]
# ## **5️⃣ Standardize Text Columns**

# %%
# 🎨 Standardize string formatting
df.columns = df.columns.str.strip()
df['Gender']   = df['Gender'].str.strip().str.title()
df['Company'] = df['Company'].str.strip().str.title()
df['Model']     = df['Model'].str.strip().str.title()
df['Color']     = df['Color'].str.strip().str.title()
df['Body_Style']     = df['Body_Style'].str.strip().str.title()
df['Dealer_Region']     = df['Dealer_Region'].str.strip().str.title()

# %% [markdown]
# # **6️⃣ Validate Cleaned Data**

# %%
# ✅ Quick sanity check
print("Final Shape:", df.shape)
print("Null Values:\n", df.isnull().sum())
df.head()
# Out:
# Final Shape: (23906, 11)
# Null Values:
#  Car_id           0
# Date             0
# Gender           0
# Annul_Income     0
# Company          0
# Model            0
# Transmission     0
# Color            0
# Price            0
# Body_Style       0
# Dealer_Region    0
# dtype: int64
#          Car_id       Date Gender  Annul_Income   Company       Model  \
# 0  C_CND_000001 2022-01-02   Male         13500      Ford  Expedition
# 1  C_CND_000002 2022-01-02   Male       1480000     Dodge     Durango
# 2  C_CND_000003 2022-01-02   Male       1035000  Cadillac    Eldorado
# 3  C_CND_000004 2022-01-02   Male         13500    Toyota      Celica
# 4  C_CND_000005 2022-01-02   Male       1465000     Acura          Tl
#
#   Transmission       Color  Price Body_Style Dealer_Region
# 0         Auto       Black  26000        Suv    Middletown
# 1         Auto       Black  19000        Suv        Aurora
# 2       Manual         Red  31500  Passenger    Greenville
# 3       Manual  Pale White  14000        Suv         Pasco
# 4         Auto         Red  24500  Hatchback    Janesville

# %% [markdown]
# # **7️⃣  Save Cleaned Dataset**

# %%
# 💾 Save cleaned dataset
df.to_csv('Cleaned_Car_Sales_Dataset.csv', index=False)

print("✅ Data cleaning complete! Cleaned file saved as 'Cleaned_Car_Sales_Dataset.csv'")
# Out:
# ✅ Data cleaning complete! Cleaned file saved as 'Cleaned_Car_Sales_Dataset.csv'
